# %%
from pylab import *
import sys
sys.path.append('./JSAnimation')
from JSAnimation import IPython_display
from matplotlib import animation

# %%
n = 40
m = 20
E_app = 100000
G = load("transitionMatrix.npy")
x = linalg.eig(G)

# %%
index = 30
steps = 20
h = zeros((m * (n - 1) + n + 1, steps))
h[:,0] = real(x[1][:,index])
for i in range(1, steps):
    h[:,i] = G.dot(h[:,i-1])

# %%
fig = plt.figure()
ax = plt.axes(xlim=(0, n - 1), ylim=(amin(h[m*(n-1):m*(n-1)+n,:]), amax(h[m*(n-1):m*(n-1)+n,:])))
line, = ax.plot([], [], lw=2)

def init():
    line.set_data([], [])
    return line,

def animate(i):
    line.set_data(range(n), h[m*(n-1):m*(n-1)+n,i])
    return line,

animation.FuncAnimation(fig, animate, init_func=init, frames=steps, interval=20, blit=True)
# Out:
# <script language="javascript">
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     document.getElementById(this.slider_id).max = this.frames.length - 1;
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src = this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function(){t.anim_step_forward();}, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function(){t.anim_step_reverse();}, this.interval);
#   }
# </script>
#
# <div class="animation" align="center">
#     <img id="_anim_imgAKZCMDFUQVCNARQY">
#     <br>
#     <input id="_anim_sliderAKZCMDFUQVCNARQY" type="range" style="width:350px" name="points" min="0" max="1" step="1" value="0" onchange="animAKZCMDFUQVCNARQY.set_frame(parseInt(this.value));"></input>
#     <br>
#     <button onclick="animAKZCMDFUQVCNARQY.slower()">&#8211;</button>
#     <button onclick="animAKZCMDFUQVCNARQY.first_frame()"><img class="anim_icon" src="..."></button>
#     <button onclick="animAKZCMDFUQVCNARQY.previous_frame()"><img class="anim_icon" src="..."></button>
#     <button onclick="animAKZCMDFUQVCNARQY.reverse_animation()"><img class="anim_icon" src="..."></button>
#     <button onclick="animAKZCMDFUQVCNARQY.pause_animation()"><img class="anim_icon" src="..."></button>
#     <button onclick="animAKZCMDFUQVCNARQY.play_animation()"><img class="anim_icon" src="..."></button>
#     <button onclick="animAKZCMDFUQVCNARQY.next_frame()"><img class="anim_icon" src="..."></button>
#     <button onclick="animAKZCMDFUQVCNARQY.last_frame()"><img class="anim_icon" src="..."></button>
#     <button onclick="animAKZCMDFUQVCNARQY.faster()">+</button>
#   <form action="#n" name="_anim_loop_selectAKZCMDFUQVCNARQY" class="anim_control">
#     <input type="radio" name="state" value="once" > Once </input>
#     <input type="radio" name="state" value="loop" checked> Loop </input>
#     <input type="radio" name="state" value="reflect" > Reflect </input>
#   </form>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_imgAKZCMDFUQVCNARQY";
#     var slider_id = "_anim_sliderAKZCMDFUQVCNARQY";
#     var loop_select_id = "_anim_loop_selectAKZCMDFUQVCNARQY";
#     var frames = new Array(0);
#
#   frames[0] = "...\
# AAAPYQAAD2EBqD+naQAAIABJREFUeJzs3XmYFNW9//FPzwzDDDuKICgggqgxbhAkEnHBuKPGFdAb\
# zVVJNC7BLUav+74lohLXxLig4C+iRMUYN0SvilHcorKLijCooOyzMDP1++N7y6pBhGGmq05V9fv1\
# PD5WzzDdZ3q6q86nz/mek/M8zxMAAAAAxKDIdQMAAAAAFA4CCAAAAIDYEEAAAAAAxIYAAgAAACA2\
# BBAAAAAAsSGAAAAAAIgNAQQAAABAbAggAAAAAGJDAAEAAAAQGwIIAAAAgNgQQAAAAADEhgACAAAA\
# IDYEEAAAAACxIYAAAAAAiA0BBAAAAEBsCCAAAAAAYkMAAQAAABAbAggAAACA2BBAAAAAAMSGAAIA\
# AAAgNgQQAAAAALEhgAAAAACIDQEEAAAAQGwIIAAAAABiQwABAAAAEBsCCAAAAIDYEEAAAAAAxIYA\
# AgAAACA2BBAAAAAAsSGAAAAAAIgNAQQAAABAbAggAAAAAGJDAAEAAAAQGwIIAAAAgNgQQAAAAADE\
# hgACAAAAIDYEEAAAAACxIYAAAAAAiA0BBAAAAEBsCCAAAAAAYkMAAQAAABAbAggAAACA2BBAEmbV\
# qlW67LLLdOCBB2qTTTZRUVGRHnjgASdtGT9+vPr166fy8nJ17txZp5xyipYsWeKkLQAAAMgGAkjC\
# fP3117rqqqs0c+ZM7bLLLpKkXC4XezvuvPNOHXfccerUqZNuueUWjRw5UuPHj9e+++6r6urq2NsD\
# AACAbChx3QA01K1bNy1atEidO3fWtGnTNGDAgNjbUFNTo4suukh77bWXnnvuue++PmjQIB166KG6\
# 9957dcYZZ8TeLgAAAKQfIyAJU1paqs6dO0uSPM9b77/95z//qcGDB6tNmzZq166dhg4dqo8//rjZ\
# bfjwww+1bNkyDRs2rMHXDznkELVu3Vrjx49v9mMAAACgMBFAUuqhhx7S0KFD1a5dO91444265JJL\
# 9PHHH2uPPfbQZ5991qz79qdYlZeXf+975eXleu+995p1/wAAAChcBJAUWrlypc466yyNHDlSkyZN\
# 0m9/+1udf/75mjp1qjzP07XXXtus+99mm22Uy+X0v//7vw2+PnPmTC1evFiVlZX69ttvm/UYAAAA\
# KEzUgKTQ888/r2XLlmn48OFavHjxd18vKirSbrvtpsmTJ3/3tfr6etXU1DTqfsvKyiRJnTp10rHH\
# HqsHHnhA22+/vX7xi19owYIFOvPMM9WiRQvV1taqsrJSHTt2zO8vBgAAgMwjgKTQ7NmzJUlDhgxZ\
# 5/fbt2//3fGDDz6ok046qVH3W1VVpdLSUknS3XffrcrKSp133nk677zzJEm//OUv1adPHz3++ONq\
# 06ZNc34FAAAAFCgCSArV19dLksaOHavNN9/8e98vKQn+rIMHD9b999/fqPsN/1y7du00ceJEzZ8/\
# X5999pl69uyp7t27a9CgQercubPatWvXvF8CAAAABYkAkkJ9+vSRJG222WY/OAri6927t3r37t3k\
# x+revbu6d+8uSVq6dKmmTZumY445psn3BwAAgMJGEXoKHXDAAWrXrp2uvfZa1dbWfu/74bqQfLrw\
# wgtVX1+vs88+O5L7BwAAQPYxApJAY8aM0dKlS7Vw4UJJ0pNPPqnPP/9cknTWWWepXbt2uvPOO/XL\
# X/5S/fr10/Dhw9WpUyd9/vnnmjRpkvbYYw/dfvvtzWrD9ddfrw8//FADBw5USUmJJk6cqOeff17X\
# XHON+vfv3+zfEQAAAIUp521otzvErlevXt/t5ZHL5STZpoS5XE7z5s1Tjx49JElTpkzR9ddfr6lT\
# p6q6ulpbbrmlBg8erDPOOEO77rprs9rwzDPP6Morr9T06dNVV1ennXfeWeecc46OOuqo5v1yAAAA\
# KGgEEAAAAACxoQYEAAAAQGwIIAAAAABiQxF6wlRUVKiiosJ1MwAAAPADunbtqq5du7puRmoRQBKk\
# oqJC3boNkTTDdVMAAADwA/baay+NGzeOENJEBJAEsZGPGRo+fKzOP397181JnVGjRmn06NGum5Fa\
# PH9Nx3PXPDx/Tcdz1zw8f01XqM/dAw9It902XVOm/JcqKioIIE1EAEmgtm23V79+/Vw3I3U6dOjA\
# 89YMPH9Nx3PXPDx/Tcdz1zw8f01XqM/dxImuW5ANFKEn0OrVrlsAAACAta1c6boF2UAASaDKStct\
# AAAAwNoIIPlBAEkgAggAAEDyrFrlugXZQABJIKZgNc2IESNcNyHVeP6ajueueXj+mo7nrnl4/pqu\
# UJ87RkDyI+d5nue6ETDvvPOO+vfvrwEDpunf/y68wi4AAIAk23df6aWX3pHUX9OmTSvIQvx8YAQk\
# gZiCBQAAkDyMgOQHASSBCCAAAADJQw1IfhBAEogaEAAAgORhBCQ/CCAJxAgIAABA8hBA8oMAkkCM\
# gAAAACQPASQ/CCAJVFMj1dW5bgUAAAB8tbVSdbXrVmQDASShKHICAABIDvpm+UMASSiG+AAAAJKD\
# vln+EEASihc5AA
