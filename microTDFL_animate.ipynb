# %%
from pylab import *
import sys
sys.path.append('./JSAnimation')
from JSAnimation import IPython_display
from matplotlib import animation

# %%
# create a simple animation
fig = plt.figure()
ax = plt.axes(xlim=(0, 10), ylim=(-2, 2))
line, = ax.plot([], [], lw=2)

x = np.linspace(0, 10, 1000)

def init():
    line.set_data([], [])
    return line,

def animate(i):
    line.set_data(x, np.cos(i * 0.02 * np.pi) * np.sin(x - i * 0.02 * np.pi))
    return line,

animation.FuncAnimation(fig, animate, init_func=init,
                        frames=100, interval=20, blit=True)
# Out:
# <script language="javascript">
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     document.getElementById(this.slider_id).max = this.frames.length - 1;
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src = this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function(){t.anim_step_forward();}, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function(){t.anim_step_reverse();}, this.interval);
#   }
# </script>
#
# <div class="animation" align="center">
#     <img id="_anim_imgAEPIWEZEVSVHJTQR">
#     <br>
#     <input id="_anim_sliderAEPIWEZEVSVHJTQR" type="range" style="width:350px" name="points" min="0" max="1" step="1" value="0" onchange="animAEPIWEZEVSVHJTQR.set_frame(parseInt(this.value));"></input>
#     <br>
#     <button onclick="animAEPIWEZEVSVHJTQR.slower()">&#8211;</button>
#     <button onclick="animAEPIWEZEVSVHJTQR.first_frame()"><img class="anim_icon" src="..."></button>
#     <button onclick="animAEPIWEZEVSVHJTQR.previous_frame()"><img class="anim_icon" src="..."></button>
#     <button onclick="animAEPIWEZEVSVHJTQR.reverse_animation()"><img class="anim_icon" src="..."></button>
#     <button onclick="animAEPIWEZEVSVHJTQR.pause_animation()"><img class="anim_icon" src="..."></button>
#     <button onclick="animAEPIWEZEVSVHJTQR.play_animation()"><img class="anim_icon" src="..."></button>
#     <button onclick="animAEPIWEZEVSVHJTQR.next_frame()"><img class="anim_icon" src="..."></button>
#     <button onclick="animAEPIWEZEVSVHJTQR.last_frame()"><img class="anim_icon" src="..."></button>
#     <button onclick="animAEPIWEZEVSVHJTQR.faster()">+</button>
#   <form action="#n" name="_anim_loop_selectAEPIWEZEVSVHJTQR" class="anim_control">
#     <input type="radio" name="state" value="once" > Once </input>
#     <input type="radio" name="state" value="loop" checked> Loop </input>
#     <input type="radio" name="state" value="reflect" > Reflect </input>
#   </form>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_imgAEPIWEZEVSVHJTQR";
#     var slider_id = "_anim_sliderAEPIWEZEVSVHJTQR";
#     var loop_select_id = "_anim_loop_selectAEPIWEZEVSVHJTQR";
#     var frames = new Array(0);
#
#   frames[0] = "...\
# AAAPYQAAD2EBqD+naQAAIABJREFUeJzs3XucjeX6x/HvGoNhnBIyk6g2StQWm2yd6LSpdBBqSkUH\
# KuWQcmaMU+UQqSgqRfZsmZTd6ZdOopJk7N2unaS2FONYymFmMLN+f1wty4oZM8w89zp83q/XvF7X\
# /Zg1c00jz7qe+76v2+f3+/0CAAAAAA/EuU4AAAAAQOygAAEAAADgGQoQAAAAAJ6hAAEAAADgGQoQ\
# AAAAAJ6hAAEAAADgGQoQAAAAAJ6hAAEAAADgGQoQAAAAAJ6hAAEAAADgGQoQAAAAAJ6hAAEAAADg\
# GQoQAAAAAJ6hAAEAAADgGQoQAAAAAJ6hAAEAAADgGQoQAAAAAJ6hAAEAAADgGQoQAAAAAJ6hAAEA\
# AADgGQoQAAAAAJ6hAAEAAADgGQoQAAAAAJ6hAAEAAADgGQoQAAAAAJ6hAAEAAADgGQoQAAAAAJ6h\
# AAEAAADgGQoQAAAAAJ6hAAEAAADgGQoQAAAAAJ6hAAEAAADgGQoQAAAAAJ6hAAEAAADgGQoQAAAA\
# AJ6hAAEAAADgGQoQAAAAAJ6hAAEAAADgGQoQAAAAAJ6hAAEAAADgGQoQAAAAAJ6hAAEAAADgGQoQ\
# AAAAAJ6hAAEAAADgGQoQAAAAAJ6hAAEAAADgGQoQAAAAAJ6hAAEAAADgGQoQAAAAAJ6hAAEAAADg\
# GQoQAAAAAJ6hACnAihUrdO+996px48aqVKmS6tWrp+uvv17ffvttkV6/Y8cO9ejRQzVr1lSlSpV0\
# 0UUXadWqVaWcNQAAABDefH6/3+86iXDUqVMnLVu2TJ07d9ZZZ52lrKwsPfHEE9q1a5c+/fRTNW7c\
# uMDX5ufn6/zzz9cXX3yhAQMG6Pjjj9e0adP0448/auXKlapfv76HPwkAAAAQPihACrBs2TK1aNFC\
# 8fHxB66tXbtWZ555pjp16qQ5c+YU+NqXXnpJN9xwgzIyMtSxY0dJ0rZt29SwYUO1b99ec+fOLfX8\
# AQAAgHBEAVJMzZs3V1xcnFasWFHg53Tp0kUfffSRNm7cGHL9rrvu0osvvqhffvlFZcuWLe1UAQAA\
# gLDDHpBi8Pv92rx5s2rUqFHo561atUrNmjU75HqLFi20Z88erVmzprRSBAAAAMIaBUgxzJ07Vxs3\
# btT1119f6OdlZWUpKSnpkOuBa3+cGQEAAABiBQVIEa1evVq9evVS69atdeuttxb6uTk5OSpfvvwh\
# 1xMSEiRJ2dnZpZIjAAAAEO7ij/wp2LRpk6644godd9xxysjIkM/nK/TzK1SooNzc3EOu5+TkHPjz\
# gmRlZSkrK+vYEgYAAECpSUpKOuxqFxQNBcgR/Prrr2rfvr1+++03LV26VLVr1z7ia5KSkg67zCpQ\
# WCQnJx/2dVlZWfrLX/7CEi0AAIAwlpycrM8//5wi5ChRgBQiJydHHTp00Nq1a/Xuu+/q9NNPL9Lr\
# mjZtqqVLl8rv94fMlixfvlyJiYlq2LDhYV+XlZWljRs36sUXX1SjRo1K5GdAeOvbt6+mTJniOg14\
# hN93bOH3HVv4fceOr7/+Wl27di1wzy+OjAKkAHl5ebr++uu1fPlyLVy4UOecc85hP2/Tpk3asWOH\
# 6tevf+DMkE6dOikjI0MLFizQddddJ8nOAZk/f746dOhwxBa8jRo1OmwXLUSfatWq8buOIfy+Ywu/\
# 79jC7xsoOgqQAvTv31+vvfaaOnTooG3btunFF18M+fOuXbtKkgYNGqTZs2dr3bp1qlu3riQrQFq1\
# aqXu3bvrv//974GT0P1+v9LS0jz/WQAAAIBwQQFSgH//+9/y+Xx67bXX9Nprr4X8mc/nO1CA+Hy+\
# Qzalx8XF6c0339SDDz6oqVOnKjs7Wy1bttTs2bPVoEEDz34GAAAAINzQhrcAH3zwgfLy8pSfn3/I\
# R15e3oHPmzVrlvLy8g7MfgRUq1ZNM2fO1NatW7Vr1y69//77TM0CAAAg5lGAAA6lpKS4TgEe4vcd\
# W/h9xxZ+30DRUYAADnHDii38vmMLv+/Ywu8bKDoKEAAAAACeoQABAAAA4BkKEAAAAACeoQABAAAA\
# 4BkKEAAAAACeoQABAAAA4BkKEAAAAACeoQABAAAA4BkKEAAAAACeoQABAAAA4BkKEAAAAACeoQAB\
# AAAA4BkKEAAAAACeoQABAAAA4BkKEAAAAACeoQABAAAA4BkKEAAAAACeoQABAAAA4BkKEAAAAACe\
# oQABAAAA4BkKEAAAAACeoQABAAAA4BkKEAAAAACeoQABAAAA4BkKEAAAAACeoQABAAAA4BkKEAAA\
# AACeoQABAAAA4BkKEAAAAACeoQABAAAA4BkKEAAAAACeoQABAAAA4BkKEAAAAACeoQABAAAA4BkK\
# EAAAAACeoQABAAAA4BkKEAAAAACeoQABAAAA4BkKEAAAAACeoQABAAAA4BkKEAAAAACeoQABAAAA\
# 4BkKEAAAAACeoQABAAAA4BkKkELs3r1bqampateunapXr664uDi98MILRXrt888/r7i4uMN+bNmy\
# pZQzBwAAAMJTvO
